# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images, test_images  = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))

# %%
model1 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history1 = model1.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 57s 30ms/step - loss: 0.3894 - accuracy: 0.8618 - val_loss: 0.3192 - val_accuracy: 0.8850
# Epoch 2/10
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.2668 - accuracy: 0.9028 - val_loss: 0.2737 - val_accuracy: 0.9018
# Epoch 3/10
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.2199 - accuracy: 0.9191 - val_loss: 0.2554 - val_accuracy: 0.9059
# Epoch 4/10
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.1891 - accuracy: 0.9305 - val_loss: 0.2590 - val_accuracy: 0.9070
# Epoch 5/10
# 1875/1875 [==============================] - 46s 24ms/step - loss: 0.1616 - accuracy: 0.9395 - val_loss: 0.2439 - val_accuracy: 0.9153
# Epoch 6/10
# 1875/1875 [==============================] - 44s 23ms/step - loss: 0.1365 - accuracy: 0.9491 - val_loss: 0.2616 - val_accuracy: 0.9136
# Epoch 7/10
# 1875/1875 [==============================] - 46s 25ms/step - loss: 0.1161 - accuracy: 0.9570 - val_loss: 0.2632 - val_accuracy: 0.9165
# Epoch 8/10
# 1875/1875 [==============================] - 44s 24ms/step - loss: 0.0983 - accuracy: 0.9636 - val_loss: 0.2783 - val_accuracy: 0.9171
# Epoch 9/10
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.0827 - accuracy: 0.9699 - val_loss: 0.2942 - val_accuracy: 0.9156
# Epoch 10/10
# 1875/1875 [==============================] - 44s 23ms/step - loss: 0.0708 - accuracy: 0.9743 - val_loss: 0.3142 - val_accuracy: 0.9139

# %%
model2 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history2 = model2.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 69s 36ms/step - loss: 0.4545 - accuracy: 0.8347 - val_loss: 0.3515 - val_accuracy: 0.8754
# Epoch 2/10
# 1875/1875 [==============================] - 65s 35ms/step - loss: 0.3036 - accuracy: 0.8889 - val_loss: 0.3038 - val_accuracy: 0.8895
# Epoch 3/10
# 1875/1875 [==============================] - 67s 36ms/step - loss: 0.2549 - accuracy: 0.9054 - val_loss: 0.2662 - val_accuracy: 0.9028
# Epoch 4/10
# 1875/1875 [==============================] - 66s 35ms/step - loss: 0.2221 - accuracy: 0.9179 - val_loss: 0.2532 - val_accuracy: 0.9057
# Epoch 5/10
# 1875/1875 [==============================] - 65s 35ms/step - loss: 0.1962 - accuracy: 0.9267 - val_loss: 0.2668 - val_accuracy: 0.9052
# Epoch 6/10
# 1875/1875 [==============================] - 65s 34ms/step - loss: 0.1732 - accuracy: 0.9345 - val_loss: 0.2564 - val_accuracy: 0.9090
# Epoch 7/10
# 1875/1875 [==============================] - 66s 35ms/step - loss: 0.1552 - accuracy: 0.9427 - val_loss: 0.2586 - val_accuracy: 0.9125
# Epoch 8/10
# 1875/1875 [==============================] - 65s 35ms/step - loss: 0.1363 - accuracy: 0.9488 - val_loss: 0.2620 - val_accuracy: 0.9124
# Epoch 9/10
# 1875/1875 [==============================] - 65s 35ms/step - loss: 0.1199 - accuracy: 0.9549 - val_loss: 0.2801 - val_accuracy: 0.9105
# Epoch 10/10
# 1875/1875 [==============================] - 66s 35ms/step - loss: 0.1074 - accuracy: 0.9599 - val_loss: 0.2807 - val_accuracy: 0.9109

# %%
model3 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128,(3 ,3),activation='relu'),
    Flatten(),
    Dense(256 ,activation='relu'),
    Dense(10 ,activation='softmax')
])

model3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history3 = model3.fit(train_images ,train_labels ,epochs=10 ,validation_data=(test_images ,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 78s 41ms/step - loss: 0.4569 - accuracy: 0.8303 - val_loss: 0.3286 - val_accuracy: 0.8802
# Epoch 2/10
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.2956 - accuracy: 0.8914 - val_loss: 0.2918 - val_accuracy: 0.8922
# Epoch 3/10
# 1875/1875 [==============================] - 79s 42ms/step - loss: 0.2491 - accuracy: 0.9074 - val_loss: 0.2635 - val_accuracy: 0.9035
# Epoch 4/10
# 1875/1875 [==============================] - 79s 42ms/step - loss: 0.2172 - accuracy: 0.9185 - val_loss: 0.2649 - val_accuracy: 0.9018
# Epoch 5/10
# 1875/1875 [==============================] - 78s 41ms/step - loss: 0.1901 - accuracy: 0.9290 - val_loss: 0.2503 - val_accuracy: 0.9104
# Epoch 6/10
# 1875/1875 [==============================] - 76s 41ms/step - loss: 0.1651 - accuracy: 0.9382 - val_loss: 0.2827 - val_accuracy: 0.9075
# Epoch 7/10
# 1875/1875 [==============================] - 78s 42ms/step - loss: 0.1470 - accuracy: 0.9441 - val_loss: 0.2604 - val_accuracy: 0.9130
# Epoch 8/10
# 1875/1875 [==============================] - 75s 40ms/step - loss: 0.1295 - accuracy: 0.9506 - val_loss: 0.2770 - val_accuracy: 0.9136
# Epoch 9/10
# 1875/1875 [==============================] - 78s 42ms/step - loss: 0.1143 - accuracy: 0.9558 - val_loss: 0.2888 - val_accuracy: 0.9114
# Epoch 10/10
# 1875/1875 [==============================] - 80s 43ms/step - loss: 0.1014 - accuracy: 0.9613 - val_loss: 0.3137 - val_accuracy: 0.9131

# %%
def plot_history(history,title):
    plt.figure(figsize=(12 ,6))

    plt.subplot(2 ,3 ,1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title(f'{title}:\n Loss vs. Epochs')

    plt.subplot(2 ,3 ,2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title(f'{title}:\n Accuracy vs. Epochs')

"""    plt.subplot(2 ,3 ,3)
    plt.plot(history.history['precision'], label='Training Precision')
    plt.plot(history.history['val_precision'], label='Validation Precision')
    plt.legend()
    plt.title(f'{title}:\n Precision vs. Epochs')

    plt.subplot(2 ,3 ,6)
    plt.plot(history.history['recall'], label='Training Recall')
    plt.plot(history.history['val_recall'], label='Validation Recall')
    plt.legend()
    plt.title(f'{title}:\n Recall vs. Epochs')"""
# Out:
# "    plt.subplot(2 ,3 ,3)\n    plt.plot(history.history['precision'], label='Training Precision')\n    plt.plot(history.history['val_precision'], label='Validation Precision')\n    plt.legend()\n    plt.title(f'{title}:\n Precision vs. Epochs')\n    \n    plt.subplot(2 ,3 ,6)\n    plt.plot(history.history['recall'], label='Training Recall')\n    plt.plot(history.history['val_recall'], label='Validation Recall')\n    plt.legend()\n    plt.title(f'{title}:\n Recall vs. Epochs')"

# %%
plot_history(history1 ,'Model 1')
plot_history(history2 ,'Model 2')
plot_history(history3 ,'Model 3')
